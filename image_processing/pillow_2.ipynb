# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter, ImageEnhance

# %%
im1 = Image.open('img1.jpg')
im2 = Image.open('img2.jpg')
im3 = Image.open('img3.jpeg')
im3 = Image.open('img4.jpg')

# %%
im5 = Image.new('RGB',(800,800),(0,255,255))
im5
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
im55=im5.copy()
fnt = ImageFont.truetype('font.ttf',40)
d = ImageDraw.Draw(im55)
# sraw hello at 10,10 with color
d.text((10,10),"Hello",font= fnt,fill = (100,100,100))
d.text((10,60),"how",font= fnt,fill = (100,100,100))
d.text((10,100),"old",font= fnt,fill = (100,100,100))
d.text((10,140),"are",font= fnt,fill = (100,100,100))
d.text((10,180),"you?",font= fnt,fill = (100,100,100))
im55.show()

# %%
im11 = im1.copy()
d = ImageDraw.Draw(im11)
# draw a  outer circle
d.ellipse((100,100,200,200),fill = (255,0,0))
# draw a inner circle
d.ellipse((120,120,180,180),fill=(0,225,0))
im11.show()

# %%
im33 = im3.copy()
d = ImageDraw.Draw(im33)
# draw a rectangle on the top and bottom of the image 100px height and black
d.rectangle((0,0,im33.width,100),fill=(0,0,0))
d.rectangle((0, im33.height - 100,im33.width,im33.height),fill=(0,0,0))
# add a text in the rectangle in the middle with white
fnt = ImageFont.truetype('font.ttf',40)
d.text((im33.width / 2 - 100, 30),"Happy New",font=fnt,fill=(255,255,255),align='center')
d.text((im33.width / 2 - 100, im33.height - 70),"Year 2023",font=fnt,fill=(255,255,255),align='center')
im33.show()

# %%
logo = Image.open('star.png')
logo
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1080x1080>

# %%
logo = Image.resize((100,100))
logo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\91831\Documents\DigiPodium\image_processing\pillow_2.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91831/Documents/DigiPodium/image_processing/pillow_2.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> logo = Image.resize((100,100))
#       <a href='vscode-notebook-cell:/c%3A/Users/91831/Documents/DigiPodium/image_processing/pillow_2.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> logo
#
# File c:\Users\91831\miniconda3\lib\site-packages\PIL\Image.py:76, in __getattr__(name)
#      74         deprecate(name, 10, f"{enum.__name__}.{name}")
#      75         return enum[name]
# ---> 76 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'PIL.Image' has no attribute 'resize'
